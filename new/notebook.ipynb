# %% [markdown]
# # Model Testing

# %%
from data_loader import get_train_test_splits, get_combined_dataset
from preprocessor import apply_minmax_scaling
from model_list import SINGLE_TARGET_MODELS, MULTI_TARGET_MODELS
import pandas as pd
from model_testing import fit_and_evaluate_model
from IPython.display import display, HTML

X_train, X_test, y_train, y_test = get_train_test_splits(test_size=0.2)
X_train, y_train, X_train_scaler, y_train_scaler = apply_minmax_scaling(
    X_train, y_train
)
X_test, y_test, X_test_scaler, y_test_scaler = apply_minmax_scaling(X_test, y_test)
df = get_combined_dataset(X_train, y_train, X_test, y_test)
display(df)

print(f"Number of single-target models: {len(SINGLE_TARGET_MODELS)}")
print(f"Number of multi-target models: {len(MULTI_TARGET_MODELS)}")
# Out:
# Train years: 2015 to 2083
# Test years: 2084 to 2100
#           x    y  bedrock_elevation  precipitation  air_temperature  \
# 0       0.0  1.0           0.118762       0.180874         0.795808
# 1       0.0  1.0           0.163009       0.175715         0.793057
# 2       0.0  1.0           0.042803       0.173047         0.791427
# 3       0.0  1.0           0.135461       0.178002         0.790789
# 4       0.0  1.0           0.087251       0.190951         0.790841
# ...     ...  ...                ...            ...              ...
# 194097  0.0  0.0           0.347665       0.592466         0.831212
# 194098  0.0  0.0           0.326669       0.557774         0.838175
# 194099  0.0  0.0           0.365826       0.535849         0.843655
# 194100  0.0  0.0           0.416587       0.533697         0.851775
# 194101  0.0  0.0           0.342699       0.533793         0.865899
#
#         ocean_temperature  year  distance_to_pole  bedrock_below_sea_level  \
# ...

# %% [markdown]
# ## Single Target Models

# %% [markdown]
# ### Broad Testing

# %%
single_target_results = {}
for name, model in SINGLE_TARGET_MODELS:
    print(f"Evaluating {name} for single-target regression:")
    results = fit_and_evaluate_model(
        model, X_train, y_train, X_test, y_test, multi=False
    )
    single_target_results[name] = results

print("\nSingle-target regression results:")
for name, results in single_target_results.items():
    print(f"\n{name}:")
    print(results)
# Out:
# Evaluating Linear Regression for single-target regression:
# Evaluating Ridge for single-target regression:
# Evaluating Lasso for single-target regression:
# Evaluating ElasticNet for single-target regression:
# Evaluating Lars for single-target regression:
# Evaluating LassoLars for single-target regression:
# Evaluating OrthogonalMatchingPursuit for single-target regression:
# Evaluating BayesianRidge for single-target regression:
# c:\Users\samma\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_bayes.py:53: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.3 and will be removed in 1.5
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 for name, model in SINGLE_TARGET_MODELS:
#       3     print(f"Evaluating {name} for single-target regression:")
# ...

# %% [markdown]
# ### Refined Testing

# %% [markdown]
# ### Model Interpretation

# %% [markdown]
# ## Multi-Target Models

# %%
multi_target_results = {}
for name, model in multi_target_models:
    print(f"Evaluating {name} for multi-target regression:")
    results = fit_and_evaluate_model(
        model, X_train, y_train, X_test, y_test, multi=True
    )
    multi_target_results[name] = results

print("\nMulti-target regression results:")
for name, results in multi_target_results.items():
    print(f"\n{name}:")
    print(results)

# %% [markdown]
# ## Sequential Models
